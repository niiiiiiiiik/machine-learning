# %% [markdown]
# ## variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=100

# %%
### declaring and assigning variable 
age=32
height=6.1
name="Nikhil"
is_student=False


#### printing the variable 
print("age",age)
print("height",height)
print("name",name)
print("Studnet",is_student)
# Out:
# age 32
# height 6.1
# name Nikhil
# Studnet False

# %%
###naming convenction 
## variable name should be descriptive 
## they must always start with a letter or an _
### it can contain letter numbers , _
### variables names are case sensitive 

##valid name 

first_name="Nik"
last_name="Yadav"

###invalid name

#2age=30
#first-name="Nikhil"
#@name="nik"


First_name="nik"

first_name==First_name
# Out:
# False

# %%
### understanding variable type 
## python i s dynamically typed - type of a variable is determined at runtime 

age=25 #int

# %%
height=6.1 #float
name="Nik" #string 
is_student=False #boolean
