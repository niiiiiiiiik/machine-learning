# %%
from sklearn.datasets import make_regression
import numpy as np

# %%
X,y=make_regression(n_samples=4,n_features=1,n_informative=1,n_targets=1,noise=80,random_state=13)

# %%
import matplotlib.pyplot as plt
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X,y)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([78.35063668])

# %%
reg.intercept_
# Out:
# 26.15963284313262

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='Red')

# %%
## lets apply gradient descent assuming slop is contstant 78
# lets assume starting value of b=0

# %%
y_pred=((78.35 * X)+0).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='Red',label='ols')
plt.plot(X,y_pred,color='green',label='b=0')
plt.legend()
plt.show()

# %%
m=78.35
b=0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
loss_slope= -2 * np.sum(y-m*X.ravel()-b)
loss_slope
# Out:
# -209.27763408209216

# %%
lr=0.1

step_size=loss_slope*lr

# %%
step_size
# Out:
# -20.927763408209216

# %%
b=b-step_size

# %%
b
# Out:
# 20.927763408209216

# %%
y_pred1=((78.35*X)+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='Red',label='ols')
plt.plot(X,y_pred,color='green',label='b=0')
plt.plot(X,y_pred1,color='yellow',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2 * np.sum(y-m*X.ravel()-b)
loss_slope
# Out:
# -41.85552681641845

# %%
step_size=loss_slope*lr
step_size
# Out:
# -4.185552681641845

# %%
b=b-step_size

# %%
b
# Out:
# 25.11331608985106

# %%
y_pred2=((78.35*X)+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='Red',label='ols')
plt.plot(X,y_pred,color='green',label='b=0')
plt.plot(X,y_pred1,color='yellow',label='b={}'.format(b))
plt.plot(X,y_pred2,color='pink',label='b={}'.format(b))
plt.legend()
plt.show()

# %%
loss_slope=-2 * np.sum(y-m*X.ravel()-b)
loss_slope
# Out:
# -8.37110536328369

# %%
step_size=loss_slope*lr
step_size
# Out:
# -0.837110536328369

# %%
b=b-step_size

# %%
y_pred3=((78.35*X)+b).reshape(4)

# %%
plt.scatter(X,y)
plt.plot(X,reg.predict(X),color='Red',label='ols')
plt.plot(X,y_pred,color='green',label='b=0')
plt.plot(X,y_pred1,color='yellow',label='1 st'.format(b))
plt.plot(X,y_pred2,color='pink',label='2 nd'.format(b))
plt.plot(X,y_pred3,color='purple',label='3 rd'.format(b))
plt.legend()
plt.show()

# %%
b=-100
m=78.35
lr=0.01

epochs=100

for i in range(epochs):
    loss_slope=-2 * np.sum(y-m*X.ravel()-b)
    step_size=loss_slope*lr
    b=b-step_size
    y_pred=m*X+b
    plt.plot(X,y_pred)
        
        
plt.scatter(X,y)
